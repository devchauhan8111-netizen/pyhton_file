# %%
result = float(input("enter your first number : "))
while True:
    op = input(""" Enter your any given operation
        (-) subtract
        (+) Addition sum
        (/) Division
        (*) multiplication
        (%) percentage 
        input the operation : """)
    if op not in ["-", "subtract", "+", "Addition", "/", "Division", "*", "multiplication", "%", "percentage"]:
            break
    Num2 = float(input("enter your number"))
    if op == "+" or op.lower() == "addition" or op.lower() == "sum":
        print("Answer",(result + Num2))
        result = result + Num2
    elif op == "-" or op.lower() == "subtract":
        if result<Nu2:
            print("Answer",(Num2 - result))
            result  = Num2 - result
        elif result>Nu2: 
            print("Answer",(result - Num2))
            result = result - Num2
    elif op == "*" or op.lower() == "multiplication":
         print("Answer",(result * Num2))
         result = result * Num2
        
    elif op == "/" or op.lower() == "division":
        n = input("Enter whether the result should be placed in numerator(n) or denominator(d) : ")
        if n == "n":
            if Num2 == 0 :
                print("The division is not defined.")
            else:
                print(f"Division output is, {result / Num2}")
                result  = result/Num2
        elif n == "d":
            if result  == 0:
                print("The division operation is not defined.")
            else:
                print(f" Division output is, {Num2/result}")
                result = Num2/result
        else:
            print("You entered a incorrect input." )
            
    elif op == "%" or op.lower() == "percentage":
        m = input("Enter whether the result should be placed in numerator(n) or denominator(d) : ")
        if m == "n":
            if Num2 == 0 :
                print("The division is not defined.")
            else:
                print(f"Division output is, {result % Num2}")
                result  = result%Numm2
        elif m == "d":
            if result  == 0:
                print("The division operation is not defined.")
            else:
                print(f" Division output is, {Num2%result}")
                result = Num2%result
        else:
            print("You entered a incorrect input." )
    else:
        break
